# %% [markdown]
# # Proyecto 3

# %%
# Importamos librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
# %matplotlib inline

# %%
# Descargar datos
file_temp = 'Datos de temperatura.csv'
df_temp = pd.read_csv(file_temp)
df_temp
# Out:
#           Fecha  Max  Min  Media  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0    01/01/2016   23    7   15.0         NaN         NaN         NaN
# 1    02/01/2016   23   11   17.0         NaN         NaN         NaN
# 2    03/01/2016   22   13   17.5         NaN         NaN         NaN
# 3    04/01/2016   18    8   13.0         NaN         NaN         NaN
# 4    05/01/2016   22    7   14.5         NaN         NaN         NaN
# 5    06/01/2016   21    9   15.0         NaN         NaN         NaN
# 6    07/01/2016   19    9   14.0         NaN         NaN         NaN
# 7    08/01/2016   22    8   15.0         NaN         NaN         NaN
# 8    09/01/2016   23    7   15.0         NaN         NaN         NaN
# 9    10/01/2016   20   11   15.5         NaN         NaN         NaN
# 10   11/01/2016   24    9   16.5         NaN         NaN         NaN
# 11   12/01/2016   17    8   12.5         NaN         NaN         NaN
# 12   13/01/2016   14    8   11.0         NaN         NaN         NaN
# ...

# %%
# Cargamos hoja de calculo en un dataframe
file_temp = 'Datos de temperatura.csv'
df_temp = pd.read_csv(file_temp, usecols=[ 'Media'])
# df_temp = pd.read_csv(file_temp, index_col='Fecha', usecols=['Fecha', 'Media'])
df_temp
# Out:
#      Media
# 0     15.0
# 1     17.0
# 2     17.5
# 3     13.0
# 4     14.5
# 5     15.0
# 6     14.0
# 7     15.0
# 8     15.0
# 9     15.5
# 10    16.5
# 11    12.5
# 12    11.0
# 13    14.0
# 14    15.0
# 15    13.0
# 16    15.0
# 17    14.0
# 18    11.5
# 19    14.5
# 20    14.5
# 21    15.0
# 22    12.0
# 23    12.0
# 24    15.0
# 25    16.5
# 26    15.0
# 27     8.0
# 28    11.5
# 29    15.5
# ..     ...
# 336   19.0
# 337   17.0
# 338   17.5
# 339   17.0
# 340   18.0
# 341   18.0
# 342   17.5
# 343   16.5
# 344   15.0
# 345   16.5
# 346   17.0
# 347   15.5
# 348   16.0
# 349   16.5
# 350   17.5
# 351   17.5
# 352   17.5
# 353   17.0
# 354   16.0
# 355   16.0
# 356   16.0
# 357   14.5
# 358   16.5
# 359   15.5
# 360   16.0
# 361   15.0
# 362   18.0
# 363   17.0
# 364   15.5
# 365   15.5
#
# [366 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#df_temp.plot(figsize=(8,6));
plt.plot(df_temp.index, df_temp.loc[:,'Media'], 'r*', label = 'media')

# %%
plt.figure(figsize=(8,6))
plt.plot(df_temp, 'ro', label = 'media')
plt.xlabel('$Fechas$')
plt.ylabel('$Temperatura (°)$')
plt.show()

# %%
import pyomo_utilities

# %%
x = df_temp('Fecha')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-deb393408fbf> in <module>()
# ----> 1 x = df_temp('Fecha')
#
# TypeError: 'DataFrame' object is not callable

# %%
beta = pyomo_utilities.curve_polyfit(x, y, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b8315138159f> in <module>()
# ----> 1 beta = pyomo_utilities.curve_polyfit(df_temp, 1)
#
# TypeError: curve_polyfit() missing 1 required positional argument: 'order'
