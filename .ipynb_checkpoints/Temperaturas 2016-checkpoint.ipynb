# %% [markdown]
# # Proyecto 3

# %%
# Importamos librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
# %matplotlib inline

# %%
# Descargar datos
file_temp = 'Datos de temperatura.csv'
df_temp = pd.read_csv(file_temp)
df_temp
# Out:
#           Fecha  Max  Min  Media  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0    01/01/2016   23    7   15.0         NaN         NaN         NaN
# 1    02/01/2016   23   11   17.0         NaN         NaN         NaN
# 2    03/01/2016   22   13   17.5         NaN         NaN         NaN
# 3    04/01/2016   18    8   13.0         NaN         NaN         NaN
# 4    05/01/2016   22    7   14.5         NaN         NaN         NaN
# 5    06/01/2016   21    9   15.0         NaN         NaN         NaN
# 6    07/01/2016   19    9   14.0         NaN         NaN         NaN
# 7    08/01/2016   22    8   15.0         NaN         NaN         NaN
# 8    09/01/2016   23    7   15.0         NaN         NaN         NaN
# 9    10/01/2016   20   11   15.5         NaN         NaN         NaN
# 10   11/01/2016   24    9   16.5         NaN         NaN         NaN
# 11   12/01/2016   17    8   12.5         NaN         NaN         NaN
# 12   13/01/2016   14    8   11.0         NaN         NaN         NaN
# ...

# %%
# Cargamos hoja de calculo en un dataframe
file_temp = 'Datos de temperatura.csv'
df_temp = pd.read_csv(file_temp, usecols=[ 'Media'])
# df_temp = pd.read_csv(file_temp, index_col='Fecha', usecols=['Fecha', 'Media'])
df_temp
# Out:
#      Media
# 0     15.0
# 1     17.0
# 2     17.5
# 3     13.0
# 4     14.5
# 5     15.0
# 6     14.0
# 7     15.0
# 8     15.0
# 9     15.5
# 10    16.5
# 11    12.5
# 12    11.0
# 13    14.0
# 14    15.0
# 15    13.0
# 16    15.0
# 17    14.0
# 18    11.5
# 19    14.5
# 20    14.5
# 21    15.0
# 22    12.0
# 23    12.0
# 24    15.0
# 25    16.5
# 26    15.0
# 27     8.0
# 28    11.5
# 29    15.5
# ..     ...
# 336   19.0
# 337   17.0
# 338   17.5
# 339   17.0
# 340   18.0
# 341   18.0
# 342   17.5
# 343   16.5
# 344   15.0
# 345   16.5
# 346   17.0
# 347   15.5
# 348   16.0
# 349   16.5
# 350   17.5
# 351   17.5
# 352   17.5
# 353   17.0
# 354   16.0
# 355   16.0
# 356   16.0
# 357   14.5
# 358   16.5
# 359   15.5
# 360   16.0
# 361   15.0
# 362   18.0
# 363   17.0
# 364   15.5
# 365   15.5
#
# [366 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#df_temp.plot(figsize=(8,6));
plt.plot(df_temp.index, df_temp.loc[:,'Media'], 'r*', label = 'media')

# %%
import pyomo_utilities

# %%
beta = pyomo_utilities.curve_polyfit(df_temp.index, df_temp.loc[:,'Media'], 1)
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 2
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.11.1\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 1.1060426235198975
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# ...

# %%
beta
# Out:
# array([  1.78397507e+01,   1.12510257e-03])

# %%
yhat1 = beta[0]+beta[1]*(df_temp.index)

plt.figure(figsize=(8,6))
plt.plot(df_temp.index, df_temp.loc[:,'Media'], '*b', label = 'datos')
plt.plot(df_temp.index, yhat1, '-r', label = 'ajuste')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %%
beta2 = pyomo_utilities.curve_polyfit(df_temp.index, df_temp.loc[:,'Media'], 2)
yhat2 = beta2[0]+beta2[1]*(df_temp.index)+beta2[2]*(df_temp.index)**2

plt.figure(figsize=(8,6))
plt.plot(df_temp.index, df_temp.loc[:,'Media'], '*b', label = 'datos')
plt.plot(df_temp.index, yhat1, '-r', label = 'ajuste 1')
plt.plot(df_temp.index, yhat2, '-g', label = 'ajuste 2')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 3
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.11.1\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.05114412307739258
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# ...

# %%
beta3 = pyomo_utilities.curve_polyfit(df_temp.index, df_temp.loc[:,'Media'], 3)
yhat3 = beta3[0]+beta3[1]*(df_temp.index)+beta3[2]*(df_temp.index)**2+beta3[3]*(df_temp.index)**3

plt.figure(figsize=(8,6))
plt.plot(df_temp.index, df_temp.loc[:,'Media'], '*b', label = 'datos')
plt.plot(df_temp.index, yhat1, '-r', label = 'ajuste 1')
plt.plot(df_temp.index, yhat2, '-g', label = 'ajuste 2')
plt.plot(df_temp.index, yhat3, '-k', label = 'ajuste 3')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 4
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.11.1\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.017551898956298828
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# ...

# %%
beta4 = pyomo_utilities.curve_polyfit(df_temp.index, df_temp.loc[:,'Media'], 4)
yhat4 = beta4[0]+beta4[1]*(df_temp.index)+beta4[2]*(df_temp.index)**2+beta4[3]*(df_temp.index)**3+beta4[4]*(df_temp.index)**4

plt.figure(figsize=(8,6))
plt.plot(df_temp.index, df_temp.loc[:,'Media'], '*b', label = 'datos')
plt.plot(df_temp.index, yhat1, '-r', label = 'ajuste 1')
plt.plot(df_temp.index, yhat2, '-g', label = 'ajuste 2')
plt.plot(df_temp.index, yhat3, '-k', label = 'ajuste 3')
plt.plot(df_temp.index, yhat4, '-m', label = 'ajuste 4')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 5
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.11.1\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.01604318618774414
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# ...

# %%
beta5 = pyomo_utilities.curve_polyfit(df_temp.index, df_temp.loc[:,'Media'], 5)
yhat5 = beta5[0]+beta5[1]*(df_temp.index)+beta5[2]*(df_temp.index)**2+beta5[3]*(df_temp.index)**3+beta5[4]*(df_temp.index)**4+beta5[5]*(df_temp.index)**5

plt.figure(figsize=(8,6))
plt.plot(df_temp.index, df_temp.loc[:,'Media'], '*b', label = 'datos')
plt.plot(df_temp.index, yhat1, '-r', label = 'ajuste 1')
plt.plot(df_temp.index, yhat2, '-g', label = 'ajuste 2')
plt.plot(df_temp.index, yhat3, '-k', label = 'ajuste 3')
plt.plot(df_temp.index, yhat4, '-m', label = 'ajuste 4')
plt.plot(df_temp.index, yhat5, '-r', label = 'ajuste 5')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 6
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.11.1\x3a Solved To Acceptable Level.
#   Termination condition: optimal
#   Id: 1
#   Error rc: 0
#   Time: 0.021055936813354492
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# ...

# %%
beta6 = pyomo_utilities.curve_polyfit(df_temp.index, df_temp.loc[:,'Media'], 6)
yhat6 = beta6[0]+beta6[1]*(df_temp.index)+beta6[2]*(df_temp.index)**2+beta6[3]*(df_temp.index)**3+beta6[4]*(df_temp.index)**4+beta6[5]*(df_temp.index)**5+beta6[6]*(df_temp.index)**6

plt.figure(figsize=(8,6))
plt.plot(df_temp.index, df_temp.loc[:,'Media'], 'b', label = 'datos')
plt.plot(df_temp.index, yhat1, '-r', label = 'ajuste 1')
plt.plot(df_temp.index, yhat2, '-g', label = 'ajuste 2')
plt.plot(df_temp.index, yhat3, '-k', label = 'ajuste 3')
plt.plot(df_temp.index, yhat4, '-m', label = 'ajuste 4')
plt.plot(df_temp.index, yhat5, '-r', label = 'ajuste 5')
plt.plot(df_temp.index, yhat6, '-y', label = 'ajuste 6')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()
# Out:
# WARNING - Loading a SolverResults object with a warning status into model=unknown; message from solver=Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 7
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: warning
#   Message: Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
#   Termination condition: maxIterations
#   Id: 400
#   Error rc: 0
# ...

# %%
# np.array([x**i for i in range(21)]).T.dot(beta20_lasso)
beta6_lasso = pyomo_utilities.curve_polyfit(df_temp.index, df_temp.loc[:,'Media'], 6, reg_mode = 'lasso', reg_coef = 0.01)
yhat6 = np.array([(df_temp.index)**i for i in range(7)]).T.dot(beta6_lasso)

plt.figure(figsize=(8,6))
plt.plot(df_temp.index, df_temp.loc[:,'Media'], 'b', label = 'datos')
plt.plot(df_temp.index, yhat1, '-r', label = 'ajuste 1')
plt.plot(df_temp.index, yhat2, '-g', label = 'ajuste 2')
plt.plot(df_temp.index, yhat3, '-k', label = 'ajuste 3')
plt.plot(df_temp.index, yhat4, '-m', label = 'ajuste 4')
plt.plot(df_temp.index, yhat5, '-r', label = 'ajuste 5')
plt.plot(df_temp.index, yhat6, '-y', label = 'ajuste 6 lasso')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()
# Out:
# WARNING - Loading a SolverResults object with a warning status into model=unknown; message from solver=Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 7
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: warning
#   Message: Ipopt 3.11.1\x3a Maximum Number of Iterations Exceeded.
#   Termination condition: maxIterations
#   Id: 400
#   Error rc: 0
# ...
