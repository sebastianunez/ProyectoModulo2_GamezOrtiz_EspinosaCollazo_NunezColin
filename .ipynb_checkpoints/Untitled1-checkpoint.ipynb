# %% [markdown]
# # SEGUNDO PROYECTO DE SIMULACIÓN MATEMÁTICA
#
# > ## Natasha Gámez
# >## Luz Clara Espinosa
# >## Sebastian Núñez

# %% [markdown]
# # 1. Valuación de una empresa.
# En el mercado accionario donde se compran y vender miles de títulos de diferentes acciones al día, los precios de las mismas están determinados por la oferta y demanda de los involucrados, lo que hace que la cotización no sea el valor real de la acción y una forma de conocer cuánto realmente vale un título es mediante la valuación de empresas para determinar su valor intrínseco.

# %% [markdown]
# # Objetivo general:
# * En base a la opción que ofrece Python para manipular datos financieros fácilmente, podemos obtener la información de la empresa a valuar y así apoyado de funciones estadísticas y probabilísticas determinar el valor de cada acción de la empresa.

# %% [markdown]
# # Objetivos específicos
# * <img style="float: right; margin: 0px 0px 15px 15px;" src="http://bolsamexicanadevalores.com.mx/wp-content/uploads/salida-a-bolsa-alpek.jpg" width="300px" height="100px" />
# * Tomar los datos de la empresa ALPEK (ALPEKA.MX), la cual es una compañía controladora mexicana, las compañías petroquímicas más grande de México, la cual está integrada por dos segmentos de negocios: productos de poliéster (1) y productos plásticos y químicos (2).
#
# * Calcular Ratios Financieros por medio de los datos obtenidos, estos Ratios son:
# > * Free cash flow
# > * Enterprise value
# > * Valor del equity entre número de acciones disponibles
# * $Beta$
#
# * Hacer una valuación por el método de Análisis fundamental, para poder hacer una comparación entre el valor actual de las acciones de esta empresa contra el valor obtenido por medio de nuestra valuación.

# %% [markdown]
# # Marco Teórico
# ## Para hacer  la valuación utilizamos un método llamado Análisis Fundamental.
# El análisis fundamental, dentro del análisis bursátil, pretende conocer y evaluar el auténtico valor del título o acción, llamado valor fundamental. Este valor es utilizado con el objetivo de predecir el rendimiento futuro que se espera del título (criterio financiero).
#
# Así, mediante la investigación de las propiedades intrínsecas (fundamentales) poder calcular el valor de la empresa y por ende de sus acciones.
#
# Para esta investigación, son necesarios diversas herramientas de análisis fundamental.
# Las herramientas de análisis más habituales son:
# > * Los estados financieros periódicos.
# * Análisis de Ratios Financieros
#     * Los ratios financieros (o indicadores financieros) son magnitudes relativas de dos valores numéricos seleccionados extraídos de los estados financieros de una empresa.
# * Técnicas de valuación de activos o empresas.
# * Previsiones económicas: análisis del entorno.
# * Información económica en general.
# * Cualquier tipo de información adicional que afecte al valor de un título.
#
# Utilizamos varios diferentes Ratios Financieros, entre ellos:
# > * Free cash flow: Flujo de caja o fondos libre, en inglés denominado free cash flow (FCF). Es el dinero disponible en la empresa una vez cubiertas las necesidades de reinversión en activos fijos y en necesidades operativas de fondos, considerando que no existe deuda y que por consiguiente no hay cargas financieras.
# * Enterprise value: es el Valor de la Empresa, en sentido general, descontando la liquidez (Caja, Bancos... liquidez acreedora de la mercantil con entidades), considerándose como el valor de las obligaciones que asume o asumiría el potencial comprador (patrimonio neto o valor del capital + deuda financiera neta).
# * Valor del equity: es el Valor del Capital en los términos más amplios, es decir el precio que recibirían los accionistas a cambio de la venta de su sociedad en funcionamiento.

# %% [markdown]
# # <font  FACE="Century Gothic" color = #E74C3C> Modelo utilizado </font>
#
# Los datos obtenidos para esta valuación fueron sacados de la Bolsa Mexicana de Valores (BMV), de los reportes financieros presentados por las empresas que cotizan, en este caso "Alpeka". Dichos valores son datos como: Estado de flujos de efectivo, número de acciones en circulación, deudas asociadas, activos financieros, entre muchos otros.

# %% [markdown]
# ## <font FACE="Century Gothic"color= ##64A4FC  > Ecuaciones </font>
#
# Para estos cálculos, más que cualquier otra cosa fueron utilizados métodos algorítmicos como son las matrices, sus determinantes, vectores, y funciones entre ellas. Además, utilizamos ciertas funciones estadísticas como se muestra a continuación:
#
#
# ![image.png](attachment:image.png)
#
# Esta es la ecuacion que se relaciona con lo aplicado y visto en clase, utilizamos otras ecuaciones y funciones que describimos a lo largo del proyecto, pero la principal con aplicacion en los temas del curso es la anterior.

# %% [markdown]
# ## LOS PASOS QUE SE EMPLEARAN SON EN EL SIGUIENTE ORDEN.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### PRIMERO SEÑALAR QUE ESTE ES EL PRECIO DE CIERRE DE MERCADO DE LA EMPRESA(ES DECIR COMO COTIZA ACTUALMENTE EN LA BOLSA DE VALORES)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PASO 1: FCFF

# %%
E = 9863279  #Utilidad de Operación
T = 2357916  #Impuestos a la utilidad
DA = 2559732 #Amortizaciones 
WC = (-2922298) # Capital de trabajo
CX = 9337286 # Capex
def FCFF(E,T,DA,WC,CX): #Flujo Libre de Efectivo
    return E-T+DA-WC-CX
FCFF(E,T,DA,WC,CX)
# Out:
# 3650107

# %% [markdown]
# ## PASO 2: DEUDA DE LA EMPRESA

# %%
PF= 2857220  #Pasivo Financiero LP
PFL=  22201154 #Pasivo Financiero CP
DT =  25058374 #Deuda Total (PF+PFL)
EQ= 41722259 #Capital Contable 
DEUDA_Y_EQUITY= EQ+DT 
wd= DT/DEUDA_Y_EQUITY #Porcentaje de el costo de deuda
we= EQ/DEUDA_Y_EQUITY #Porcentaje del costo de capital
rf =0.074 #Tasa de Bono M a 10 años 
wd, we
# Out:
# (0.37523414909828723, 0.6247658509017128)

# %% [markdown]
# ### KD Es el costo de los creditos con diferentes bancos. Se calcula con una media ponderada de los tasas de interes que cobra cada banco
# ![image.png](attachment:image.png)

# %%
kd= 0.044

# %% [markdown]
# ### BETA =  Este porcentaje es la sencibilidad que tienen los precios de cierre de la accion con respecto a lo que influyen en el IPC(indice de precios y cotizaciones)
# ### Se Calcula Con:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
import numpy as np
from statistics import variance
# %matplotlib inline

# %% [markdown]
# ### Para el calculo de la beta importamos los cierres de ajuste de la empresa a valuar y los del IPC

# %%
def load_adj_caE(ticker, data_source, start_date, end_date):
    panel_data = data.DataReader(ticker, data_source, start_date, end_date)
    ca = panel_data.loc['Adj Close']
    all_weekdays = pd.date_range(start=start_date, end=end_date, freq='M')
    ca = ca.reindex(all_weekdays)
    ca = ca.fillna(method='ffill')
    return ca

# %%
ticker = ['ALPEKA.MX']
data_source = 'yahoo'
start_date = '2012-10-31'
deend_date = '2017-10-31'
caa = load_adj_caE(ticker, data_source, start_date, end_date)

# %% [markdown]
# ## Cierres Ajustados Mensuales de ALPEKA.MX (Por 5 Años)

# %%
caa.plot(figsize=(8,6), c='m');

# %% [markdown]
# ## Cierres Ajustados Mensuales del IPC(Por 5 Años)

# %%
ticker1 = ['^MXX'] 
data_source = 'yahoo'
start_date = '2012-10-31'
end_date = '2017-10-31'
cai = load_adj_caE(ticker1, data_source, start_date, end_date)

# %%
cai.plot(figsize=(8,6), c='g');

# %%
ticker = ['ALPEKA.MX','^MXX']
data_source = 'yahoo'
start_date = '2012-10-31'
end_date = '2017-10-31'
ca = load_adj_caE(ticker, data_source, start_date, end_date)
ca
# Out:
#             ALPEKA.MX          ^MXX
# 2012-10-31  33.806713  41619.960938
# 2012-11-30  34.696880  41833.519531
# 2012-12-31  34.449612  43705.828125
# 2013-01-31  31.235106  45278.058594
# 2013-02-28  28.801973  44120.988281
# 2013-03-31  28.801973  44120.988281
# 2013-04-30  28.694935  42263.480469
# 2013-05-31  24.249104  41588.320313
# 2013-06-30  24.249104  41588.320313
# 2013-07-31  28.635527  40837.878906
# 2013-08-31  28.635527  40837.878906
# 2013-09-30  27.923498  40185.230469
# 2013-10-31  28.052315  41038.648438
# 2013-11-30  28.052315  41038.648438
# 2013-12-31  28.052315  41038.648438
# 2014-01-31  26.444864  40879.750000
# 2014-02-28  22.394749  38782.890625
# 2014-03-31  23.099550  40461.601563
# 2014-04-30  22.335188  40711.558594
# 2014-05-31  22.335188  40711.558594
# 2014-06-30  24.806952  42737.171875
# 2014-07-31  23.834129  43817.691406
# 2014-08-31  23.834129  43817.691406
# 2014-09-30  24.528997  44985.660156
# 2014-10-31  23.645521  45027.519531
# ...

# %%
# Se calculan los rendimientos de ambos por que son los datos a usar en el calculo de la beta 
def rendimientos(ca):
    Emp =(np.log(ca/ca.shift(1)))[1:]
    return Emp

# %%
rend2= rendimientos(ca)
rend_alpek= rendimientos(caa)
rend_mxx = rendimientos(cai)

# %%
rend2.plot(figsize=(8,6))

# %%
covar= np.cov(rend2)[5][5]
covar
# Out:
# 0.00077181124090741474

# %%
var = np.var(rend_mxx)
variance= pd.Series(var).values
variance
# Out:
# array([ 0.00054926])

# %% [markdown]
# ### BETA

# %%
Beta = covar/variance # FUNCION DE BETA
Beta
# Out:
# array([ 1.40517912])

# %%
MRP = Beta*(0.14-rf)
KE = MRP + rf
KE
# Out:
# array([ 0.16674182])

# %%
def wacc(kd,wd,KE,we): # COSTO TOTAL DE CAPITAL Y  PASIVOS
    return (kd*wd*(1-0.3)+KE*we)
wacc(kd,wd,KE,we)
# Out:
# array([ 0.11573181])

# %%
UN= 4992896 # Utilidad Neta
Div=4007581 # Dividendos Pagados
def ROE(UN,EQ): #Rendimiento 
    return (UN/EQ)
PR= (Div/UN) # Porcentaje de los dividendos respecto a la UN
G = ROE(UN,EQ)*(1-PR) 
W = wacc(kd,wd,KE,we) #Costo de Capital (Función arriba)

# %% [markdown]
# ## PASO 3: VALOR REAL DE LA EMPRESA Y SUS ACCIONES

# %%
ENV = FCFF(E,T,DA,WC,CX)/(W-G) #VALOR REAL DE TODA LA EMPRESA
ENV
# Out:
# array([ 39625218.56276464])

# %%
Efectivo_Equivalentes= 2934969 
EV = 25271327
NACC = 2116637251 # Numero de Acciones en circulacion en la Bolsa Mexicana de Valores
Valor_Intrinseco= (EV/NACC)*1000 #Valor real de la acción 
Valor_Intrinseco
# Out:
# 11.939375529775177

# %% [markdown]
# ## LA EMPRESA ESTA INFLADA EN LA BOLSA POR 69.34 % PUES SU VALOR INTRINSECO ES = $ 11.9393

# %% [markdown]
# ## Y   SU COTIZACION = $20.22

# %% [markdown]
# ## <font FACE="Century Gothic"color= ##64A4FC  > Conclusiones </font>
#
# Es muy común que las acciones de cualquier empresa en el mercado estén sobrevaluadas, o infladas por diversas razones. Es de gran utilidad para cualquier persona, empresa o interesado en comprar acciones saber los valores reales para poder hacer juicios basados en hechos y números.
# Para poder llegar al resultado de una valuación certera, es necesario pasar por varios procesos de obtención de datos: fórmulas, bases de datos, informes, leer los libros de finanzas de una empresa, etc., hay muchas formas de obtener esta información. Llevar a cabo estos procesos puede ayudar a uno a entender mucho mejor como se mueve el dinero en este sistema que a veces puede llegar a ser un tanto confuso. Pero para todas aquellas personas que lo tienen el tiempo para hacer estas valuaciones presentamos aquí este algoritmo que los ayudará en el proceso.

# %% [markdown]
# ## <font FACE="Century Gothic"color= ##64A4FC  > Referencias </font>
# * http://www.enciclopediafinanciera.com/analisisfundamental.htm
#
# * https://www.bmv.com.mx/docs-pub/visor/visorXbrl.html?docins=../ifrsxbrl/ifrsxbrl_786335_2017-03_1.zip#/visorXbrl
# * https://finance.yahoo.com/quote/ALPEKA.MX?p=ALPEKA.MX
# * https://relopezbriega.github.io/blog/2015/06/27/probabilidad-y-estadistica-con-python/
