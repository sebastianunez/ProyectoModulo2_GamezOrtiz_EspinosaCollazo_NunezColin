# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def load_adj_close(ticker, data_source, start_date, end_date):
    panel_data = data.DataReader(ticker, data_source, start_date, end_date)
    ca = panel_data.loc['Adj Close']
    all_weekdays = pd.date_range(start=start_date, end=end_date)
    ca = ca.reindex(all_weekdays)
    ca = ca.fillna(method='ffill')
    return ca

# %%
ticker = ['GMEXICOB.MX', '^MXX']
data_source = 'yahoo'
start_date = '2012-10-31'
end_date = '2017-10-31'
ca = load_adj_close(ticker, data_source, start_date, end_date)

# %%
def mu_std_daily_ret(ca):
    daily_returns = (np.log(ca/ca.shift(1)))[1:]
    return daily_returns
daily_returns= mu_std_daily_ret(ca)

# %%
def load_adj_close(ticker, data_source, start_date, end_date):
    panel_data = data.DataReader(ticker, data_source, start_date, end_date)
    cai = panel_data.loc['Adj Close']
    all_weekdays = pd.date_range(start=start_date, end=end_date)
    cai = ca.reindex(all_weekdays)
    cai = cai.fillna(method='ffill')
    return cai

# %%
ticker = ['^MXX']
data_source = 'yahoo'
start_date = '2012-10-31'
end_date = '2017-10-31'
cai = load_adj_close(ticker, data_source, start_date, end_date)
def mu_std_daily_ret(cai):
    daily_returnsi = (np.log(cai/cai.shift(1)))[1:]
    return daily_returns
daily_returnsi= mu_std_daily_ret(cai)
daily_returnsi
# Out:
#             GMEXICOB.MX      ^MXX
# 2012-11-01     0.000000  0.000000
# 2012-11-02     0.000000  0.000000
# 2012-11-03     0.000000  0.000000
# 2012-11-04     0.000000  0.000000
# 2012-11-05     0.012393  0.002452
# 2012-11-06     0.006610 -0.000036
# 2012-11-07    -0.014695 -0.017156
# 2012-11-08    -0.013220 -0.004407
# 2012-11-09    -0.013397 -0.003768
# 2012-11-10     0.000000  0.000000
# 2012-11-11     0.000000  0.000000
# 2012-11-12     0.010732  0.004485
# 2012-11-13     0.003391  0.005336
# 2012-11-14    -0.030439 -0.008019
# 2012-11-15    -0.010524 -0.004347
# 2012-11-16     0.017479  0.006313
# 2012-11-17     0.000000  0.000000
# 2012-11-18     0.000000  0.000000
# 2012-11-19     0.000000  0.000000
# 2012-11-20     0.007889  0.008618
# 2012-11-21     0.016562  0.011685
# 2012-11-22     0.012244  0.008705
# 2012-11-23     0.001192 -0.002687
# 2012-11-24     0.000000  0.000000
# 2012-11-25     0.000000  0.000000
# 2012-11-26     0.004518 -0.000985
# ...

# %%
c= np.cov(daily_returns)
v = np.var(daily_returnsi)
c
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        ...,
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   2.63624066e-05,  -1.59482175e-05],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,  -1.59482175e-05,   9.64804337e-06]])

# %%
E = 9863279
T = 2357916
DA =1964196 
WC = -2922298
CX = 9337286
FCFF= E-T+DA-WC-CX
FCFF
# Out:
# 3054571

# %%
dkgkf
